# %% [markdown]
# # Setup

# %% [markdown]
# **Run the following cell before doing anything else**. Alternatively, you can select **Run - Run All Cells** in the menu.

# %%
import numpy as np

# %% [markdown]
# # Computations in slides

# %% [markdown]
# ## Slide 15 - Computation of Value Function

# %% [markdown]
# In this example, we need to solve the system:
#
# \begin{align*}
# V(1)&=0.3(2 + V(2)) + 0.6(2 + V(4)) + 0.1(-2 + V(5))\\
# V(2)&=0.4(4 + V(1)) + 0.5(1 + V(3)) + 0.1(-3 + V(5))\\
# V(3)&=0.8(2 + V(2)) + 0.1(1 + V(4)) + 0.1(-1 + V(5))\\
# V(4)&=0.2(2 + V(1)) + 0.7(1 + V(3)) + 0.1(-1 + V(5))\\
# V(5)&=0
# \end{align*}
#
# We first rewrite the system in the form $AV=b$:
#
# \begin{align*}
# V(1) - 0.3V(2)-0.6V(4)&=0.3\cdot2 + 0.6\cdot 2 + 0.1\cdot(-2)\\
# -0.4V(1) + V(2) - 0.5V(3) &=0.4\cdot4 + 0.5\cdot1 + 0.1\cdot(-3)\\
# -0.8V(2) + V(3) - 0.1V(4)&=0.8\cdot2 + 0.1\cdot1 + 0.1\cdot(-1)\\
# -0.2V(1) - 0.7V(3) + V(4)&=0.2\cdot2 + 0.7\cdot1 + 0.1\cdot(-1)\\
# \end{align*}

# %%
A = np.array([
    [ 1.0, -0.3,  0.0, -0.6],
    [-0.4,  1.0, -0.5,  0.0],
    [ 0.0, -0.8,  1.0, -0.1],
    [-0.2,  0.0, -0.7,  1.0],
], dtype=np.float64)

print(A)

b = np.array([
    0.3 * 2 + 0.6 * 2 + 0.1 * (-2),
    0.4 * 4 + 0.5 * 1 + 0.1 * (-3),
    0.8 * 2 + 0.1 * 1 + 0.1 * (-1),
    0.2 * 2 + 0.7 * 1 + 0.1 * (-1),
], dtype=np.float64)

print(b)
# Out:
# [[ 1.  -0.3  0.  -0.6]
#  [-0.4  1.  -0.5  0. ]
#  [ 0.  -0.8  1.  -0.1]
#  [-0.2  0.  -0.7  1. ]]
# [1.6 1.8 1.6 1. ]

# %%
V = np.linalg.solve(A, b)
print(V)
# Out:
# [15.51196172 15.94258373 15.87559809 15.215311  ]

# %%
for i, v in enumerate(V):
    print(f'V({i+1}) = {V[i]:6.3f}')
print(f'V(5) = {0:6.3f}')
# Out:
# V(1) = 15.512
# V(2) = 15.943
# V(3) = 15.876
# V(4) = 15.215
# V(5) =  0.000

# %% [markdown]
# ## Slide 44 - Solution by Jacobi iteration

# %% [markdown]
# We want to solve the system:
#
# \begin{align*}
# V(\mathtt{h})&=\frac{2}{3}r_{\mathtt{s}}+\frac{1}{3}r_{\mathtt{w}}
# +\gamma\left[\left(\frac{2}{3}\alpha+\frac{1}{3}\right)V(\mathtt{h})+\frac{2}{3}(1-\alpha)V(\mathtt{l})\right]\\
# V(\mathtt{l})&=-\frac{3}{5}(1-\beta)+\frac{1}{5}\beta r_{\mathtt{s}}+\frac{1}{5}r_{\mathtt{w}}\\
# &+\gamma\left[\left(\frac{1}{5}(1-\beta)+\frac{3}{5}\right)V(\mathtt{h})+
# \left(\frac{1}{5}\beta+\frac{1}{5}\right)V(\mathtt{l})\right]
# \end{align*}
#
# To use a Jacobi iteration, we first write this system in the form:
# $$
# V = b + \gamma QV
# $$

# %% [markdown]
# Let's first define the parameters in the model:

# %%
alpha = 0.8
beta = 0.3
r_search = 15
r_wait = 10
gamma = 0.9

# %% [markdown]
# Now define $Q$ and $b$. We adopt the convention that $\mathtt{V[0]}=V_{\mathtt{h}}$ and $\mathtt{V[1]}=V_{\mathtt{l}}$

# %%
Q = np.array([
    [2/3 * alpha + 1/3, 2/3 * (1 - alpha)],
    [1/5 * (1 - beta) + 3/5, 1/5 * beta + 1/5],
], dtype=np.float64)


print(f'Matrix Q:\n{Q}')

b = np.array([
    2/3 * r_search + 1/3 * r_wait,
    -3/5 * (1 - beta) + 1/5 * beta * r_search + 1/5 * r_wait
])

print(f'Vector b:\n{b}')
# Out:
# Matrix Q:
# [[0.86666667 0.13333333]
#  [0.74       0.26      ]]
# Vector b:
# [13.33333333  2.48      ]

# %%
# Jacobi iteration:
V = np.zeros(2, dtype=np.float64)
n_iterations = 180
n_report = 30
for n in range(1, n_iterations + 1):
    V = b + gamma * Q @ V
    if (n % n_report == 0):
        print(f'n={n:3d}, V(high)={V[0]:10.8f}, V(low)={V[1]:10.8f}')
# Out:
# n= 30, V(high)=113.68382504, V(low)=101.43401316
# n= 60, V(high)=118.42373411, V(low)=106.17392222
# n= 90, V(high)=118.62466434, V(low)=106.37485246
# n=120, V(high)=118.63318201, V(low)=106.38337012
# n=150, V(high)=118.63354308, V(low)=106.38373119
# n=180, V(high)=118.63355839, V(low)=106.38374650

# %% [markdown]
# Let's check with a solution via LU decomposition:

# %%
A = np.eye(2, dtype=np.float64) - gamma * Q
V_lu = np.linalg.solve(A, b)
print(f' V(high)={V_lu[0]:10.8f}, V(low)={V_lu[1]:10.8f}')
# Out:
#  V(high)=118.63355907, V(low)=106.38374718

# %% [markdown]
# ## Slide 46 - Solution by Gauss-Seidel iteration

# %%
# Gauss-Seidel iteration:
V = np.zeros(2, dtype=np.float64)
n_iterations = 180
n_report = 30
for n in range(1, n_iterations + 1):
    V[0] = b[0] + gamma * Q[0, :] @ V
    V[1] = b[1] + gamma * Q[1, :] @ V
    if (n % n_report == 0):
        print(f'n={n:3d}, V(high)={V[0]:10.8f}, V(low)={V[1]:10.8f}')
# Out:
# n= 30, V(high)=115.21947040, V(low)=103.29702236
# n= 60, V(high)=118.53517952, V(low)=106.29480087
# n= 90, V(high)=118.63072419, V(low)=106.38118412
# n=120, V(high)=118.63347738, V(low)=106.38367332
# n=150, V(high)=118.63355671, V(low)=106.38374505
# n=180, V(high)=118.63355900, V(low)=106.38374712

# %% [markdown]
# Deterministic policy evaluation

# %%
alpha = 0.8
beta = 0.3
rsearch = 15
rwait = 10
rempty = -3.0
gamma = 0.9
print(f'Model parameters:\n{alpha=}, {beta=}, {rsearch=}, {rwait=}, {rempty=}, {gamma=}')
# Out:
# Model parameters:
# alpha=0.8, beta=0.3, rsearch=15, rwait=10, rempty=-3.0, gamma=0.9

# %% [markdown]
# Here are the matrices for the policy $\pi(\mathtt{high})=\mathtt{search}$, $\pi(\mathtt{low})=\mathtt{search}$:

# %%
P = np.array([[alpha, 1 - alpha], [1 - beta, beta]], dtype=np.float64)
print(P)
# Out:
# [[0.8 0.2]
#  [0.7 0.3]]

# %%
b = np.array([rsearch, rempty * (1 - beta) + rsearch * beta], dtype=np.float64)
print(b)
# Out:
# [15.   2.4]

# %%
A = np.eye(2, dtype=np.float64) - gamma * P
print(A)
# Out:
# [[ 0.28 -0.18]
#  [-0.63  0.73]]

# %%
V = np.linalg.solve(A,b)
print(V)
# Out:
# [125.07692308 111.23076923]

# %% [markdown]
# # Jacobi

# %%
n_iterations = 100
V = np.zeros(2, dtype=np.float64)
print(f'Initial approximation: {V}')
for i in range(n_iterations):
    V = b + gamma * P @ V
    print(f'Step {i + 1}: {V}')
# Out:
# Initial approximation: [0. 0.]
# Step 1: [15.   2.4]
# Step 2: [26.232 12.498]
# Step 3: [36.13668 22.30062]
# Step 4: [45.0325212 31.1872758]
# Step 5: [53.03712491 39.19105282]
# Step 6: [60.24111944 46.39497295]
# Step 7: [66.72470113 52.87854795]
# Step 8: [72.55992344 58.71376966]
# Step 9: [77.81162342 63.96546958]
# Step 10: [82.53815338 68.69199954]
# Step 11: [86.79203035 72.94587651]
# Step 12: [90.62051963 76.77436578]
# Step 13: [94.06615997 80.22000613]
# Step 14: [97.16723628 83.32108244]
# Step 15: [99.95820496 86.11205112]
# Step 16: [102.47007677  88.62392293]
# Step 17: [104.7307614   90.88460756]
# Step 18: [106.76537757  92.91922372]
# Step 19: [108.59653212  94.75037828]
# Step 20: [110.24457122  96.39841737]
# Step 21: [111.7278064   97.88165256]
# Step 22: [113.06271807  99.21656422]
# Step 23: [114.26413857 100.41798472]
# Step 24: [115.34541702 101.49926318]
# Step 25: [116.31856763 102.47241378]
# Step 26: [117.19440317 103.34824933]
# Step 27: [117.98265516 104.13650132]
# Step 28: [118.69208195 104.84592811]
# Step 29: [119.33056607 105.48441222]
# Step 30: [119.90520177 106.05904792]
# Step 31: [120.4223739  106.57622005]
# Step 32: [120.88782882 107.04167497]
# Step 33: [121.30673824 107.4605844 ]
# Step 34: [121.68375673 107.83760288]
# Step 35: [122.02307336 108.17691951]
# Step 36: [122.32845833 108.48230449]
# Step 37: [122.60330481 108.75715096]
# Step 38: [122.85066663 109.00451279]
# Step 39: [123.07329228 109.22713843]
# Step 40: [123.27365536 109.42750151]
# Step 41: [123.45398213 109.60782828]
# Step 42: [123.61627622 109.77012238]
# Step 43: [123.76234091 109.91618706]
# Step 44: [123.89379913 110.04764528]
# Step 45: [124.01211152 110.16595768]
# Step 46: [124.11859268 110.27243883]
# Step 47: [124.21442572 110.36827187]
# Step 48: [124.30067545 110.45452161]
# Step 49: [124.37830022 110.53214637]
# Step 50: [124.4481625  110.60200866]
# Step 51: [124.51103856 110.66488471]
# Step 52: [124.56762701 110.72147316]
# Step 53: [124.61855662 110.77240277]
# Step 54: [124.66439326 110.81823942]
# Step 55: [124.70564624 110.8594924 ]
# Step 56: [124.74277393 110.89662008]
# Step 57: [124.77618884 110.930035  ]
# Step 58: [124.80626227 110.96010842]
# Step 59: [124.83332835 110.9871745 ]
# Step 60: [124.85768782 111.01153397]
# Step 61: [124.87961135 111.0334575 ]
# Step 62: [124.89934252 111.05318867]
# Step 63: [124.91710057 111.07094673]
# Step 64: [124.93308283 111.08692898]
# Step 65: [124.94746685 111.101313  ]
# Step 66: [124.96041247 111.11425863]
# Step 67: [124.97206353 111.12590969]
# Step 68: [124.98254949 111.13639564]
# Step 69: [124.99198685 111.145833  ]
# Step 70: [125.00048047 111.15432662]
# Step 71: [125.00812473 111.16197088]
# Step 72: [125.01500457 111.16885072]
# Step 73: [125.02119642 111.17504257]
# Step 74: [125.02676908 111.18061524]
# Step 75: [125.03178448 111.18563064]
# Step 76: [125.03629834 111.1901445 ]
# Step 77: [125.04036081 111.19420697]
# Step 78: [125.04401704 111.19786319]
# Step 79: [125.04730764 111.2011538 ]
# Step 80: [125.05026919 111.20411534]
# Step 81: [125.05293458 111.20678073]
# Step 82: [125.05533343 111.20917958]
# Step 83: [125.05749239 111.21133855]
# Step 84: [125.05943546 111.21328161]
# Step 85: [125.06118422 111.21503038]
# Step 86: [125.06275811 111.21660426]
# Step 87: [125.0641746  111.21802076]
# Step 88: [125.06544945 111.21929561]
# Step 89: [125.06659681 111.22044297]
# Step 90: [125.06762944 111.22147559]
# Step 91: [125.0685588  111.22240496]
# Step 92: [125.06939523 111.22324139]
# Step 93: [125.07014802 111.22399417]
# Step 94: [125.07082552 111.22467168]
# Step 95: [125.07143528 111.22528143]
# Step 96: [125.07198406 111.22583021]
# Step 97: [125.07247796 111.22632411]
# Step 98: [125.07292247 111.22676863]
# Step 99: [125.07332253 111.22716869]
# Step 100: [125.07368259 111.22752874]

# %%
n_iterations = 100
V = np.zeros(2, dtype=np.float64)
print(f'Initial approximation: {V}')
for i in range(n_iterations):
    V[0] = b[0] + gamma * (P[0, 0] * V[0] + P[0, 1] * V[1])
    V[1] = b[1] + gamma * (P[1, 0] * V[0] + P[1, 1] * V[1])
    print(f'Step {i + 1}: {V}')
# Out:
# Initial approximation: [0. 0.]
# Step 1: [15.   11.85]
# Step 2: [27.933   23.19729]
# Step 3: [39.2872722  33.41424979]
# Step 4: [49.30140095 42.48173004]
# Step 5: [58.14372009 50.50061077]
# Step 6: [65.9535884 57.5859256]
# Step 7: [72.85205026 63.84499157]
# Step 8: [78.94557467 69.37385977]
# Step 9: [84.32810852 74.2576505 ]
# Step 10: [89.08261522 78.57161323]
# Step 11: [93.28237334 82.38223078]
# Step 12: [96.99211035 85.74823183]
# Step 13: [100.26900118  88.72149334]
# Step 14: [103.16354965  91.34783948]
# Step 15: [105.72036685  93.66774778]
# Step 16: [107.97885873  95.7169729 ]
# Step 17: [109.97383341  97.52709773]
# Step 18: [111.73603765  99.12602011]
# Step 19: [113.29263073 100.53838279]
# Step 20: [114.66760302 101.78595326]
# Step 21: [115.88214576 102.88795921]
# Step 22: [116.95497761 103.86138488]
# Step 23: [117.90263316 104.72123281]
# Step 24: [118.73971778 105.48075506]
# Step 25: [119.47913271 106.15165747]
# Step 26: [120.1322739  106.74428007]
# Step 27: [120.70920762 107.26775642]
# Step 28: [121.21882564 107.73015439]
# Step 29: [121.66898225 108.1386005 ]
# Step 30: [122.06661531 108.49938978]
# Step 31: [122.41785318 108.81808275]
# Step 32: [122.72810919 109.09959113]
# Step 33: [123.00216502 109.34825357]
# Step 34: [123.24424446 109.56790247]
# Step 35: [123.45807845 109.76192309]
# Step 36: [123.64696264 109.9333057 ]
# Step 37: [123.81380813 110.08469166]
# Step 38: [123.96118635 110.21841415]
# Step 39: [124.09136872 110.33653411]
# Step 40: [124.20636162 110.44087203]
# Step 41: [124.30793733 110.53303597]
# Step 42: [124.39766135 110.61444636]
# Step 43: [124.47691652 110.68635792]
# Step 44: [124.54692432 110.74987896]
# Step 45: [124.60876372 110.80598847]
# Step 46: [124.6633878 110.8555512]
# Step 47: [124.71163844 110.89933104]
# Step 48: [124.75425926 110.93800271]
# Step 49: [124.79190716 110.97216224]
# Step 50: [124.82516236 111.00233609]
# Step 51: [124.85453739 111.0289893 ]
# Step 52: [124.880485   111.05253266]
# Step 53: [124.90340508 111.07332902]
# Step 54: [124.92365088 111.09169889]
# Step 55: [124.94153443 111.10792539]
# Step 56: [124.95733136 111.12225861]
# Step 57: [124.97128513 111.13491946]
# Step 58: [124.9836108  111.14610306]
# Step 59: [124.99449832 111.15598177]
# Step 60: [125.00411551 111.16470785]
# Step 61: [125.01261058 111.17241579]
# Step 62: [125.02011446 111.17922437]
# Step 63: [125.0267428  111.18523854]
# Step 64: [125.03259775 111.19055099]
# Step 65: [125.03776956 111.19524359]
# Step 66: [125.04233793 111.19938866]
# Step 67: [125.04637327 111.2030501 ]
# Step 68: [125.04993777 111.20628432]
# Step 69: [125.05308637 111.20914118]
# Step 70: [125.0558676  111.21166471]
# Step 71: [125.05832432 111.21389379]
# Step 72: [125.06049439 111.21586279]
# Step 73: [125.06241127 111.21760205]
# Step 74: [125.06410448 111.21913838]
# Step 75: [125.06560013 111.22049545]
# Step 76: [125.06692128 111.22169417]
# Step 77: [125.06808827 111.22275304]
# Step 78: [125.0691191  111.22368835]
# Step 79: [125.07002966 111.22451454]
# Step 80: [125.07083397 111.22524433]
# Step 81: [125.07154444 111.22588896]
# Step 82: [125.07217201 111.22645839]
# Step 83: [125.07272636 111.22696137]
# Step 84: [125.07321602 111.22740566]
# Step 85: [125.07364856 111.22779812]
# Step 86: [125.07403062 111.22814478]
# Step 87: [125.07436811 111.228451  ]
# Step 88: [125.07466622 111.22872149]
# Step 89: [125.07492954 111.22896041]
# Step 90: [125.07516215 111.22917146]
# Step 91: [125.07536761 111.22935789]
# Step 92: [125.0755491  111.22952256]
# Step 93: [125.07570941 111.22966802]
# Step 94: [125.07585102 111.22979651]
# Step 95: [125.07597611 111.22991   ]
# Step 96: [125.0760866  111.23001026]
# Step 97: [125.0761842  111.23009881]
# Step 98: [125.07627041 111.23017704]
# Step 99: [125.07634656 111.23024613]
# Step 100: [125.07641383 111.23030717]
